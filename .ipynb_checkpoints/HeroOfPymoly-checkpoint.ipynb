# %%
#Import the dependencies
import pandas as pd
import numpy as np
import json

# %%
#open json1 and read
with open("purchase_data.json") as datafile:
    data1 = json.load(datafile)
    


dataframe = pd.DataFrame(data1)

dataframe.head()
# Out:
#    Age Gender  Item ID                                  Item Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN
# 0     Aelalis34
# 1        Eolo46
# 2   Assastnya25
# 3  Pheusrical25
# 4        Aela59

# %%
#open json 2 and read
with open("purchase_data2.json") as datafile:
    data2 = json.load(datafile)
dataframe2 = pd.DataFrame(data2)
dataframe2.head()
# Out:
#    Age Gender  Item ID                 Item Name  Price          SN
# 0   20   Male       93  Apocalyptic Battlescythe   4.49     Iloni35
# 1   21   Male       12                     Dawne   3.36   Aidaira26
# 2   17   Male        5                Putrid Fan   2.63      Irim47
# 3   17   Male      123         Twilight's Carver   2.55     Irith83
# 4   22   Male      154              Feral Katana   4.11  Philodil43

# %%
#conctinate dataframes
bigdata = pd.concat([dataframe, dataframe2], ignore_index=True)
bigdata.columns = bigdata.columns.str.replace('\s+', '_')
bigdata.head()
# Out:
#    Age Gender  Item_ID                                  Item_Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN
# 0     Aelalis34
# 1        Eolo46
# 2   Assastnya25
# 3  Pheusrical25
# 4        Aela59

# %%
#count the number of gamers
total_gamers = len(bigdata)
total_gamers
# Out:
# 858

# %%
#create a dataframe that lists the diffrent unique weapons and couce
unique_weapons = pd.DataFrame(bigdata["Item_Name"].value_counts())
unique_weapons.reset_index(inplace=True)

unique_weapons.columns = ["Weapon", "Count"]

unique_weapons.head()
# Out:
#                                  Weapon  Count
# 0                          Final Critic     14
# 1                           Stormcaller     12
# 2                            Arcane Gem     12
# 3  Betrayal, Whisper of Grieving Widows     11
# 4                              Crucifer     10

# %%
#Determine the average price of each weapon and appen
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-5f5e76d3d759> in <module>()
#       1 #Determine the average price of each weapon and append
# ----> 2 bigdata.groupby(['Item_Name', 'price']).sum()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4415                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4416                        **kwargs)
#    4417
#    4418     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1697         raise TypeError('invalid type: %s' % type(obj))
#    1698
# -> 1699     return klass(obj, by, **kwds)
# ...
